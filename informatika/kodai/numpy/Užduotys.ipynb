# %% [markdown]
# ### Spręstos užduotys
# * [Tomuko užduotėlė](https://klevas.mif.vu.lt/~tomukas/uzduotys/pitonas_2.html) 1. Padalinkite intervalą nuo -1.3 iki 2.5 vienodais žingsniais į 64 dalis.
# * Tomuko užduotėlė 2. Parašykite metodą, kuris grąžina masyvą `[1, 2, 3, 1, 2, 3, 1...]`, kuriame kiekvienas narys yra pakartotas $n$ kartų.
# * Tomuko užduotėlė 3. Parašykite metodą, kuris grąžina masyvą iš pirmųjų $n$ nelyginių sveikųjų skaičių.
# * Tomuko užduotėlė 4. Sukurkite masyvą dydžio 10 x 10 iš nulių ir "įrėminkite" jį vienetais.
# * Tomuko užduotėlė 5. Remiantis [numpy.lib.stride_tricks.sliding_window_view](https://numpy.org/devdocs/reference/generated/numpy.lib.stride_tricks.sliding_window_view.html) arba kitais metodais sukurkite dydžio 8 x 8 masyvą, kur 1 ir 0 išdėlioti šachmatine tvarka.
# * Tomuko užduotėlė 6. Parašykite metodą, kuris grąžina masyvą, kurio kiekvienas narys `(i,j)`-ojoje pozicijoje lygus `i+j`.
# * Tomuko užduotėlė 7. Sukurkite atsitiktinį dydžio 3×5 masyvą naudodami `np.random.rand(3, 5)` metodą ir suskaičiuokite: sumą, eilučių sumą, stulpelių sumą.
# * Tomuko užduotėlė 8. Sukurkite atsitiktinį dydžio 5×5 masyvą naudodami `np.random.rand(5, 5)`. Surūšiuokite eilutes pagal antrąjį stulpelį.
# * Codesignal užduotis (masyvo reikšmių, nelygių -1, išrikiavimas didėjimo tvarka)
# * Sukurti indeksaciją, kuri suplokština masyvą (duotas masyvas, reikia sudaryti Advanced indeksus, kurie perrenka visus to masyvo narius)

# %% [markdown]
# ## Kitos užduotys

# %% [markdown]
# **Įvairios**
#
# 1\. Kaip apskaičiuoti `arr.nbytes` nenaudojant šio metodo?
# 2\. Jei duotas `np.cumsum(arr)` rezultatas, kaip atkurti `arr?`
# 3\. Kaip atlikti `np.split(arr, div_points)`, jei duotas tik masyvas `arr` ir jo dalių ilgiai `counts`, bet neduoti `div_points?`
# 4\. Duotas masyvas `arr = np.array([7,7,7,7,1,1,1,6,6,6,6,6,-1,2])`. Komandos `arr[0:4]`, `arr[4:7]`, `arr[7:12]`, `arr[12:13]`, `arr[13:14]` grąžins iš eilės einančių vienodų narių grupes. Parašykite komandą, kuri grąžintų pradinių ir galutinių pozicijų sarašus: `start_points = [0, 4, 7, 12, 13]`, `end_points = [4, 7, 12, 13, 14]`
# 5\. Jei duoti rezultatai `idx = np.argsort(arr)` ir `arr[idx]`, kaip atkurti `arr?`
# 6\. Jei duotas `np.repeat(data, counts)` rezultatas, kaip atkurti `data` ir `counts?`
# 7\. Jei duotas `np.split(arr, div_points)` rezultatas, kaip atkurti `arr?`
# 8\. Duotas masyvas `arr`. Komanda `np.where(arr >= 3)` grąžina advanced indeksus narių, nemažesnių už 3, surikiuotus eilučių didėjimo tvarka:
#
#       arr = np.array([[2,3,4], [2,0,4], [1,3,7]])
#       np.where(arr >= 3) #Jei eilutės idx = 0, tai nariai bus stulpeliuose [1, 2], jei 1 - [2], jei 2 - [1, 2]
#       >>> (array([0, 0, 1, 2, 2]), array([1, 2, 2, 1, 2]))
#
# Kaip padaryti, kad rezultatas būtų surikiuotas ne eilučių, o stulpelių didėjimo tvarka?
#
#
# ## Užduotys, reikalaujančios remtis tam tikrais skyriais
# **Ilgesnė užduotis 1** (skyriai
#
# Sudoku galvosūkyje kvadratas $9 \times 9$ yra padalintas į 9 mažesnius $3 \times 3$ dydžio kvadratėlius. Dalis langelių yra užpildyta skaičiais nuo 1 iki 9. Į kiekvieną langelį reikia įrašyti trūkstamus skaičius nuo 1 iki 9 taip, kad kiekvienoje eilutėje, kiekviename stulpelyje ir kiekviename kvadratėlyje visi įrašyti skaičiai nuo 1 iki 9 būtų skirtingi.
#
#     arr = np.array([[5, 1, 7, 6, 9, 8, 2, 3, 4],
#                     [2, 8, 9, 1, 3, 4, 7, 5, 6],
#                     [3, 4, 6, 2, 7, 5, 8, 9, 1],
#                     [6, 7, 2, 8, 4, 9, 3, 1, 5],
#                     [1, 3, 8, 5, 2, 6, 9, 4, 7],
#                     [9, 5, 4, 7, 1, 3, 6, 8, 2],
#                     [4, 9, 5, 3, 6, 2, 1, 7, 8],
#                     [7, 2, 3, 4, 8, 1, 5, 6, 9],
#                     [8, 6, 1, 9, 5, 7, 4, 2, 3]])
#
# A. Raskite būdus atspausdinti kiekvieną šio masyvo stulpelį ir eilutę
# B. Atspausdinkite masyvą, sudarytą iš kiekvieno $8 \times 7$ stačiakampio, naudojant `np.lib.stride_tricks.sliding_window_view` metodą
# C. Atspausdinkite masyvą, sudarytą iš kiekvieno kvadratėlio, naudojant `np.reshape` metodą
# D. Patikrinkite, ar kiekvienoje eilutėje, stulpelyje ir kvadratėlyje surašyti skirtingi skaičiai nuo 1 iki 9
# E. Atspausdinkite masyvą, sudarytą iš kiekvieno kvadratėlio, naudojant `np.lib.stride_tricks.as_strided` metodą
#
# **Ilgesnė užduotis 2**
#
# Tarkime norime išrinkti tam tikras (nebūtinai skirtingų) skaičių poras iš masyvo `X = np.arange(n)`. Tuomet kiekviena šio masyvo narių pora `(i, j)` bus įtraukta arba neįtraukta. Sukurkime kitą $n \times n$ dydžio masyvą `adjacency`, sudarytą iš `True` ir `False` reikšmių, kuriame bet kuri `(i, j)`-ojoje pozicijoje reikšmė esanti `True` atitinka skaičių poros `(i, j)` įtraukimą (o `False` - neįtraukimą). Pavyzdžiui:
#
# Jei `X = np.array([0, 1, 2, 3])` ir `pairs = np.array([[0, 1], [1, 0], [3, 2], [2, 2], [2, 1]])`, tai `adjacency` bus:
#
#     [[False,  True, False, False],
#      [ True, False, False, False],
#      [False,  True,  True, False],
#      [False, False,  True, False]]
#
# Toks masyvas yra vadinamas gretimumo matrica (*angl.* adjacency matrix).
#
# * A1. Parašykite metodą, kuris grąžina visas galimas masyvo `X = np.arange(n)` (nebūtinai skirtingų) narių poras (eilės tvarka svarbi).
# * A2. Parašykite metodą, kuris grąžina šių porų gretimumo matricą.
# * B1. Parašykite metodą, kuris grąžina visas masyvo `X = np.arange(n)` narių poras `(i, j)` su sąlyga `i < j`.
# * B2. Parašykite metodą, kuris grąžina šių porų gretimumo matricą.
# * C1. Parašykite metodą, kuris grąžina visas masyvo `X = np.arange(n)` narių lygių skaičių poras (`i = j`).
# * C2. Parašykite metodą, kuris grąžina šių porų gretimumo matricą.
# * D1. Parašykite metodą, kuris grąžina visas masyvo `X = np.arange(n)` nelygių narių poras (`i < j`) arba (`i > j`).
# * D2. Parašykite metodą, kuris grąžina šių porų gretimumo matricą.
#
# Pastaba: galima remtis [šiuo šaltiniu](https://stackoverflow.com/a/70749998/3044825)
#
# **`Kitos` užduotys
#
# * Pasinagrinėti `numpy` ir `matplotlib` metodus, kuriuos apsimoka taikyti braižant funkcijų grafikus. Žr. [matematikos pamokos aprašymą](https://github.com/loijord/mokslas_2021/blob/main/Matematika/turinys.ipynb), skyrelį Programavimo užduotėlė Mantui. Nubraižyti bent vieną funkcijos grafiką.
# * Ateityje galime kurti matplotlib interakciją ([Sudėtingesnės interakcijos pavyzdys](https://stackoverflow.com/a/63887205/3044825))
# * Sukurti bent vieną metodą su dokumentacine eilute, paleisti testus naudojant `doctest.testmod(verbose=True)` komandą
# * Sukurti klasę su bent dviem metodais, iš kurių vienas yra `__init__`.
# * Pridėti šiems metodams dokumentacines eilutes ir paleisti testus.
#
# ## Resursai būsimoms pamokoms
#
# **Popular packages of Python**
# * [`itertools` library](https://docs.python.org/3/library/itertools.html) (a built-in Python module which contains high level functional constructs for working with iterable objects)
# * [`pandas` library](https://pandas.pydata.org/) (a commercial tool that offers data structures and operations for manipulating numerical tables and time series)
# * [`matplotlib` library](https://matplotlib.org/) (a plotting library for the Python programming language and its numerical mathematics extension NumPy)
# * [`igraph` library](https://igraph.org/) (a library collection for creating and manipulating graphs and analyzing networks)
# * [`numba` library](https://numba.pydata.org/) (open source JIT compiler that translates a subset of Python and NumPy code into fast machine code)
# * [Paketai, kurie dabar yra ant bangos](https://learnpython.com/blog/most-popular-python-packages/)
#
# **Interesting projects posted on GitHub repositories**
#
# * [`benchit`](https://github.com/droyed/benchit) repository by [`droyed`](https://github.com/droyed) (a tool to benchmark Python solutions on runtime performance and visualize)
# * [`stackoverflow_tag_cloud`](https://github.com/droyed/stackoverflow_tag_cloud) repository by [`droyed`](https://github.com/droyed) (a tool to produce a word cloud image with respective sizes of words being proportional to the respective occurences)
# * [`numpy_indexed`](https://github.com/EelcoHoogendoorn/Numpy_arraysetops_EP) package by [`EelcoHoogendoorn`](https://stackoverflow.com/search?q=user%3A613246+numpy_indexed) that contains efficient functionality on numpy arrays in subset of algorithms such as grouping and set operations)
# * [`matsymply`](https://github.com/loijord/matsymply) žaidybinis projektukas by [`loijord`](https://github.com/loijord) (that's me), skirtas mokytis spręsti paprastoms 7 klasės lygio lygtelėms.
# * [`numpyviz`](https://github.com/loijord/numpyviz) priemonė by [`loijord`](https://github.com/loijord) (that's me), skirta geresniam `numpy` masyvų įsivaizdavimui trimatėje erdvėje.
# * [`neuromap`](https://github.com/loijord/neuromap) priemonė by [`loijord`](https://github.com/loijord) (that's me), skirta braižytis matematikos taisyklių paaiškinimus pagal supaprastintą [Toulmino argumentacijos modelį](https://www.ematematikas.lt/forumas/klausimas-apie-kitokiu-problemu-sprendima-t14654.html).
# * [`manim`](https://3b1b.github.io/manim/) An animation engine for explanatory math videos by [`3blue1brow`](https://www.youtube.com/watch?v=aircAruvnKk) like this [in EN](https://www.youtube.com/watch?v=aircAruvnKk) or this [in LT](https://www.youtube.com/watch?v=MzwUVQfsZl8).
#
# **Mokymosi platformos**
#
# * [Cousera](https://www.coursera.org/)
# * [KhanAcademy](https://www.khanacademy.org/)
# * [Udemy](https://www.udemy.com)
# * [Udacity](https://www.udacity.com/)
# * [TribeOfAi
# * [Geogebra Interactive Simulations](https://www.geogebra.org/)
# * [Phet Interactive Simulations](https://phet.colorado.edu/)
# * [CodeSignal](https://codesignal.com/)
#
#
# **Daugiau `numpy` metodų**
#
# * `numpy`: broadcasting (arithetic operations between arrays of different shapes)
# * `numpy`: working in bit level (`np.packbits`, `np.unpackbits`)
# * `numpy`: groupby methods that returns counts of groups (`np.unique, np.bincount`)
# * `numpy`: groupby methods that returns scalar statistics of groups (`np.ufunc.reduceat` vs `numpy_indexed.groupby(...)`
# * `numpy`: groupby methods that returns group sorts (`np.lexsort` vs `np.argsort`)
# * `numpy`: indices that pads three dimensional space(`np.indices` vs `np.meshgrid`)
# * `numpy`: Cartessian product (`np.meshgrid`)
# * `numpy`: np.searchsorted
#
#
# * Advanced reshaping
# * Structured arrays
#
# * Kaip rasti svarbiausias pomasyvių savybes neiteruojant?
# * Connected components
# * Pandas virusai
# * Kalneliai
#
# * Surinkti programavimo knygas į viena
# * Egzamino sprendimas
# * numpy/physics guesses in Pqt5
# * UML diagrams
#
# * Atlikti visus indeksacijų perėjimų procesus trimatei versijai?
# * Ar įmanoma padaryti perėjimus ant ,,negražių" masyvų?
# * Perrašyti
#
# * Dokumentacijos kūrimas
# * Dokumentuoto kodo naudojimas

# %%
import numpy_indexed as npi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_236121/4157089735.py in <module>
# ----> 1 import numpy_indexed as npi
#
# ModuleNotFoundError: No module named 'numpy_indexed'
